# %%
import pandas as pd

# Carregar o arquivo CSV original
csv_original = pd.read_csv("csvs/tratados/especialidades.csv")
csv_original.head()
# Out:
#    ID         Especialidade
# 0   1            Acupuntura
# 1   2  Alergia e imunologia
# 2   3        Anestesiologia
# 3   4            Angiologia
# 4   5           Cardiologia

# %%
# Garantir que as especialidades de interesse estão em uma lista
csv_original['Especialidade']=csv_original['Especialidade'].str.upper()
csv_original.head()
# Out:
#    ID         Especialidade
# 0   1            ACUPUNTURA
# 1   2  ALERGIA E IMUNOLOGIA
# 2   3        ANESTESIOLOGIA
# 3   4            ANGIOLOGIA
# 4   5           CARDIOLOGIA

# %%
# Função para remover tudo antes do prefixo
def formatar_especialidades(especialidades_str):
    prefixo = "Especialidades/Áreas de Atuação:,"
    # Dividir a string pelo prefixo e pegar tudo após ele
    if prefixo in especialidades_str:
        return especialidades_str.split(prefixo, 1)[1].strip()
    return especialidades_str.strip()  # Retorna a string original se o prefixo não for encontrado



# Aplicar a formatação e filtragem na coluna de especialidades
csv_original['Especialidades Formatadas'] = csv_original['Especialidades'].apply(formatar_especialidades)
csv_original.head()
# Out:
#                                    Nome       CRM Data Inscrição  \
# 0                ABDALLA UBALDO FELÍCIO  36288-MG     26/04/2002
# 1             ABDENACK ESTEVES TRINDADE  25324-MG     11/04/1994
# 2  ABEL JOSÉ AGUIAR DE MAGALHÃES JÚNIOR  51723-MG     06/07/2010
# 3                   ABEL MENDONÇA ALVES  86396-MG     20/01/2021
# 4                   ABELARDO DE FREITAS   3843-MG     07/01/1964
#
#   Primeira Inscrição  Inscrição Situação  \
# 0         28/08/2001  Principal  Regular
# 1         27/08/1992  Principal  Regular
# 2         06/07/2010  Principal  Regular
# 3         20/01/2021  Principal  Regular
# 4         07/01/1964  Principal  Regular
#
#                                       Especialidades  \
# 0  Inscrições em outro estado: SP/106166 (Transfe...
# 1  Inscrições em outro estado: DF/8171 (Transferi...
# 2  Inscrições em outro estado:, Especialidades/Ár...
# 3  Inscrições em outro estado:, Especialidades/Ár...
# 4  Inscrições em outro estado:, Especialidades/Ár...
#
#                                Endereço                              Telefone  \
# 0  Exibição não autorizada pelo médico.  Exibição não autorizada pelo médico.
# 1  Exibição não autorizada pelo médico.  Exibição não autorizada pelo médico.
# 2  Exibição não autorizada pelo médico.  Exibição não autorizada pelo médico.
# 3  Exibição não autorizada pelo médico.  Exibição não autorizada pelo médico.
# 4  Exibição não autorizada pelo médico.  Exibição não autorizada pelo médico.
#
#            cidade                          Especialidades Formatadas
# 0  Belo Horizonte  MEDICINA LEGAL E PERÍCIA MÉDICA - RQE Nº: 4673...
# 1  Belo Horizonte  MEDICINA DE FAMÍLIA E COMUNIDADE - RQE Nº: 253...
# 2  Belo Horizonte  Médico sem especialidade registrada., Visto(s)...
# 3  Belo Horizonte  OFTALMOLOGIA - RQE Nº: 63380, Visto(s) Provisó...
# 4  Belo Horizonte  Médico sem especialidade registrada., Visto(s)...

# %%
# Filtrar apenas as linhas onde há especialidades de interesse
csv_filtrado = csv_original[csv_original['Especialidades Formatadas'] != ""]
csv_filtrado.head()
# Out:
#                                    Nome       CRM Data Inscrição  \
# 0                ABDALLA UBALDO FELÍCIO  36288-MG     26/04/2002
# 1             ABDENACK ESTEVES TRINDADE  25324-MG     11/04/1994
# 2  ABEL JOSÉ AGUIAR DE MAGALHÃES JÚNIOR  51723-MG     06/07/2010
# 3                   ABEL MENDONÇA ALVES  86396-MG     20/01/2021
# 4                   ABELARDO DE FREITAS   3843-MG     07/01/1964
#
#   Primeira Inscrição  Inscrição Situação  \
# 0         28/08/2001  Principal  Regular
# 1         27/08/1992  Principal  Regular
# 2         06/07/2010  Principal  Regular
# 3         20/01/2021  Principal  Regular
# 4         07/01/1964  Principal  Regular
#
#                                       Especialidades  \
# 0  Inscrições em outro estado: SP/106166 (Transfe...
# 1  Inscrições em outro estado: DF/8171 (Transferi...
# 2  Inscrições em outro estado:, Especialidades/Ár...
# 3  Inscrições em outro estado:, Especialidades/Ár...
# 4  Inscrições em outro estado:, Especialidades/Ár...
#
#                                Endereço                              Telefone  \
# 0  Exibição não autorizada pelo médico.  Exibição não autorizada pelo médico.
# 1  Exibição não autorizada pelo médico.  Exibição não autorizada pelo médico.
# 2  Exibição não autorizada pelo médico.  Exibição não autorizada pelo médico.
# 3  Exibição não autorizada pelo médico.  Exibição não autorizada pelo médico.
# 4  Exibição não autorizada pelo médico.  Exibição não autorizada pelo médico.
#
#            cidade                          Especialidades Formatadas
# 0  Belo Horizonte  MEDICINA LEGAL E PERÍCIA MÉDICA - RQE Nº: 4673...
# 1  Belo Horizonte  MEDICINA DE FAMÍLIA E COMUNIDADE - RQE Nº: 253...
# 2  Belo Horizonte  Médico sem especialidade registrada., Visto(s)...
# 3  Belo Horizonte  OFTALMOLOGIA - RQE Nº: 63380, Visto(s) Provisó...
# 4  Belo Horizonte  Médico sem especialidade registrada., Visto(s)...

# %%
# Remover a coluna 'nome_coluna'
csv_filtrado = csv_filtrado.drop(columns=['Especialidades'])
# Renomear a coluna 'coluna_antiga' para 'coluna_nova'
csv_filtrado = csv_filtrado.rename(columns={'Especialidades Formatadas': 'Especialidades'})
csv_filtrado.head()
# Out:
#                                    Nome       CRM Data Inscrição  \
# 0                ABDALLA UBALDO FELÍCIO  36288-MG     26/04/2002
# 1             ABDENACK ESTEVES TRINDADE  25324-MG     11/04/1994
# 2  ABEL JOSÉ AGUIAR DE MAGALHÃES JÚNIOR  51723-MG     06/07/2010
# 3                   ABEL MENDONÇA ALVES  86396-MG     20/01/2021
# 4                   ABELARDO DE FREITAS   3843-MG     07/01/1964
#
#   Primeira Inscrição  Inscrição Situação  \
# 0         28/08/2001  Principal  Regular
# 1         27/08/1992  Principal  Regular
# 2         06/07/2010  Principal  Regular
# 3         20/01/2021  Principal  Regular
# 4         07/01/1964  Principal  Regular
#
#                                Endereço                              Telefone  \
# 0  Exibição não autorizada pelo médico.  Exibição não autorizada pelo médico.
# 1  Exibição não autorizada pelo médico.  Exibição não autorizada pelo médico.
# 2  Exibição não autorizada pelo médico.  Exibição não autorizada pelo médico.
# 3  Exibição não autorizada pelo médico.  Exibição não autorizada pelo médico.
# 4  Exibição não autorizada pelo médico.  Exibição não autorizada pelo médico.
#
#            cidade                                     Especialidades
# 0  Belo Horizonte  MEDICINA LEGAL E PERÍCIA MÉDICA - RQE Nº: 4673...
# 1  Belo Horizonte  MEDICINA DE FAMÍLIA E COMUNIDADE - RQE Nº: 253...
# 2  Belo Horizonte  Médico sem especialidade registrada., Visto(s)...
# 3  Belo Horizonte  OFTALMOLOGIA - RQE Nº: 63380, Visto(s) Provisó...
# 4  Belo Horizonte  Médico sem especialidade registrada., Visto(s)...

# %%
# Salvar o resultado em um novo arquivo CSV
csv_original.to_csv("csvs/tratados/especialidades.csv", index=False)
csv_original.head()
# Out:
#    ID         Especialidade
# 0   1            ACUPUNTURA
# 1   2  ALERGIA E IMUNOLOGIA
# 2   3        ANESTESIOLOGIA
# 3   4            ANGIOLOGIA
# 4   5           CARDIOLOGIA
